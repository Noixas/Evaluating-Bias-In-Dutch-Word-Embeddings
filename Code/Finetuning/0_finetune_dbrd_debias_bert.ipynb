# %%
# from debias_transformers import RobertaTokenizer, RobertaForSequenceClassification
from debias_transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
import torch
from tqdm import tqdm, trange

import logging
logging.basicConfig(level=logging.INFO)

import pandas as pd
import numpy as np

from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
from pycm import ConfusionMatrix

import os
import sys 
sys.path.insert(0, os.path.abspath(os.path.join('..')))
from train import Train as RobBERTTrainer
from textdataset import TextDataset, load_and_cache_examples

# %%
# %load_ext autoreload
# %autoreload 2
import debias_finetunning as sen_debias
# Out:
# WARNING:smart_open.transport:unable to import 'smart_open.gcs', disabling that module

# %% [markdown]
# ## Change per model:
#
# 1. Model imports (e.g. BertTokenizer -> RobertaTokenizer)
#     - model name
# 2. File where bias_subspace is.
# 3. Examples files
#     - load_and_cache_examples("bert", tokenizer, "../../Rodrigo-data/Finetuning/dbrd/train")
# 4. Change name of file_pickle_stats to save stats and dont override
# 5. Where we save the model output_dir = "../../Rodrigo-data/Finetuning/dbrd/v2/bert_debiased/"

# %%
tokenizer = BertTokenizer.from_pretrained("wietsedv/bert-base-dutch-cased")
# tokenizer = RobertaTokenizer.from_pretrained("pdelobelle/robBERT-base")
# Out:
# INFO:debias_transformers.tokenization_utils_base:loading file https://s3.amazonaws.com/models.huggingface.co/bert/wietsedv/bert-base-dutch-cased/vocab.txt from cache at /home/ubuntu/.cache/torch/transformers/75d9be4cc7910048b3bdd477c435ffc46330193705f74eaf9a4f375cd3be28b2.1e00a56207196ed1759c49bdd1fa93c2fb20273d59fabb0c4c8092f7beb773c2

# %%
model = BertForSequenceClassification.from_pretrained("wietsedv/bert-base-dutch-cased")
logging.info("loaded BERTJe")
# Out:
# INFO:debias_transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/wietsedv/bert-base-dutch-cased/config.json from cache at /home/ubuntu/.cache/torch/transformers/6702c5c53edb76b65d71f73ff2d9811ba62f16257ea58e36dedceffd71290a6a.1a78bd120fe46d78b55efa59f4ffa1dafcc9242743ab9fd6629d1b56672c9119
# INFO:debias_transformers.configuration_utils:Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 3,
#   "type_vocab_size": 2,
#   "vocab_size": 30000
# }
#
# INFO:debias_transformers.modeling_utils:loading weights file https://cdn.huggingface.co/wietsedv/bert-base-dutch-cased/pytorch_model.bin from cache at /home/ubuntu/.cache/torch/transformers/e5754f612ca0f16edba5b775fdddba806751f5e4b87c5e7f16cc0c8d8d17df4d.b7c03627733fd0712f078a4d3a31ad964550f50a6113efdf874ecbcf5ddf6b53
# WARNING:debias_transformers.modeling_utils:Some weights of the model checkpoint at wietsedv/bert-base-dutch-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# WARNING:debias_transformers.modeling_utils:Some weights of BertForSequenceClassification were not initialized from the model checkpoint at wietsedv/bert-base-dutch-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:loaded BERTJe

# %% [markdown]
# ## Create a training config

# %%
from train_config import Config
config = Config()
config.model_type = 'bert'
config.evaluate_dataset = "../../Rodrigo-data/Finetuning/dbrd/eval"

# %% [markdown]
# ## Create bias direction

# %%
#Get bias dir
# Rodrigo-data/bias_subspace/bias_subspace_k10_nl_large30000k.npy
# file_bias_subspace = "../../Rodrigo-data/bias_subspace/Robbert_ForFinetune-bias_subspace_k50_nl_large30000k" #Robbert bias
file_bias_subspace = "../../Rodrigo-data/bias_subspace/bias_subspace_k50_nl_large30000k" #Bert bias

bias_subspace = sen_debias.get_bias_direction(model,tokenizer, #reload from cache 
    from_cache = True,    
    filename_cache= file_bias_subspace)
bias_direction = bias_subspace[0] #just use the direction for testing   
bias_direction = torch.tensor(bias_direction).to(torch.device("cuda"))

# %%
bias_direction.shape
# Out:
# torch.Size([768])

# %% [markdown]
# ## Load in the data
# We use `load_and_cache_examples` to load in the training data, this will produce a tokenized version with torch tensors.
#
# For the test and evaluation sets, we'll use the following `evaluate` function, since we're in the end interested in a dataframe with all inputs and predictions.

# %%
def evaluate(dataset, model,debias,bias_dir):
    df = pd.read_table(dataset + ".labels.txt", header=None, names=['labels'])
    df['sentence'] = pd.read_table(dataset + ".sentences.txt", header=None, names=['sentence'])
    model.eval() # disable dropout etc.
    
    mask_padding_with_zero = True
    block_size = 512
    results = []

    # file_bias_subspace = "../Rodrigo-data/bias_subspace/bias_subspace_k"+str(k_dim_file)+"_nl_large"+str(pairs_aumount)+"k"
    # bias_dir = sen_debias.get_bias_direction(model_nl,tokenizer_nl,from_cache = True,filename_cache= file_bias_subspace)
    for row in tqdm(df.iterrows(), total=len(df), mininterval=1, position=1, leave=True):
        index = row[0]
        sentence = row[1]['sentence']
        label = row[1]['labels']

        #tokens = roberta.encode(sentence)
        tokenized_text = tokenizer.tokenize(sentence)[-block_size + 3: -1]
        if len(tokenized_text) is 0: #avoid sentence that couldnt be tokenized in bertje
                            continue
        tokenized_text = tokenizer.encode(tokenized_text)
        # tokenized_text = tokenizer.encode(tokenizer.tokenize(sentence)[- block_size + 3 : -1])

        input_mask = [1 if mask_padding_with_zero else 0] * len(tokenized_text)

        pad_token = tokenizer.convert_tokens_to_ids(tokenizer.pad_token)
        while len(tokenized_text) < block_size:
            tokenized_text.append(pad_token)
            input_mask.append(0 if mask_padding_with_zero else 1)
            #segment_ids.append(pad_token_segment_id)
            #p_mask.append(1)

        #self.examples.append([tokenizer.build_inputs_with_special_tokens(tokenized_text[0 : block_size]), [0], [0]])
        batch = tuple(torch.tensor(t).to(torch.device("cuda")) for t in [tokenized_text[0 : block_size - 3], input_mask[0 : block_size- 3], [0], [1] if label else [0]])
        inputs = {"input_ids": batch[0].unsqueeze(0), "attention_mask": batch[1].unsqueeze(0), "labels": batch[3].unsqueeze(0),
        "remove_bias":debias,"bias_dir":bias_direction}
        with torch.no_grad():
            outputs = model(**inputs)

            results.append({"true": label, "predicted": outputs[1][0].argmax().item()})

    model.train() # make sure the model is back in training mode
    return results

# %%
train_dataset = load_and_cache_examples("bert", tokenizer, "../../Rodrigo-data/Finetuning/dbrd/train")
# Out:
# INFO:textdataset:Creating features from dataset file at ../../Rodrigo-data/Finetuning/dbrd
# ../../Rodrigo-data/Finetuning/dbrd/train
# INFO:textdataset:Saving features into cached file ../../Rodrigo-data/Finetuning/dbrd/bert_cached_lm_512_train

# %%
model.train()
logging.info("Put BERT in training mode")
# Out:
# INFO:root:Put BERT in training mode

# %%
# You can use the following code to adjust the training size to experiment with the benefits of pretraining. It will not likely get better though ...
train_dataset.examples  = train_dataset.examples[:100]
# 46min after iteration 1:13

# %%
DEBIAS_BOOL = False #Used to indicate whether to debias or not accross the notebook

# %%
# Random interesting insight, num examples with bertje is 19525 while in robbert is 19528, this is probably due to some bad sentences 
# in the data which robbert could tokenize while bert tokenizer kept crashing so had to avoid the tokenized sentences with 0 elements.  -Rodrigo
RobBERTTrainer.train(config, train_dataset, model, tokenizer, evaluate,debias=DEBIAS_BOOL, bias_dir=bias_direction)
# Out:
# rning_rate=1.29e-6, loss=0.1, step=1955]
#
# Iteration:  21%|██        | 1006/4882 [02:16<08:31,  7.58it/s, learning_rate=1.29e-6, loss=0.1, step=1955]
#
# Iteration:  21%|██        | 1008/4882 [02:16<09:17,  6.95it/s, learning_rate=1.26e-6, loss=0.382, step=1956]
#
# Iteration:  21%|██        | 1010/4882 [02:17<08:50,  7.30it/s, learning_rate=1.26e-6, loss=0.382, step=1956]
#
# Iteration:  21%|██        | 1012/4882 [02:17<08:37,  7.48it/s, learning_rate=1.26e-6, loss=0.382, step=1956]
#
# Iteration:  21%|██        | 1014/4882 [02:17<08:30,  7.57it/s, learning_rate=1.26e-6, loss=0.382, step=1956]
#
# Iteration:  21%|██        | 1016/4882 [02:17<09:12,  7.00it/s, learning_rate=1.23e-6, loss=0.172, step=1957]
#
# Iteration:  21%|██        | 1018/4882 [02:18<08:47,  7.33it/s, learning_rate=1.23e-6, loss=0.172, step=1957]
#
# Iteration:  21%|██        | 1020/4882 [02:18<08:35,  7.50it/s, learning_rate=1.23e-6, loss=0.172, step=1957]
#
# Iteration:  21%|██        | 1022/4882 [02:18<08:29,  7.57it/s, learning_rate=1.23e-6, loss=0.172, step=1957]
#
# Iteration:  21%|██        | 1024/4882 [02:19<09:11,  6.99it/s, learning_rate=1.2e-6, loss=0.1, step=1958]
#
# Iteration:  21%|██        | 1026/4882 [02:19<08:46,  7.32it/s, learning_rate=1.2e-6, loss=0.1, step=1958]
#
# Iteration:  21%|██        | 1028/4882 [02:19<08:34,  7.49it/s, learning_rate=1.2e-6, loss=0.1, step=1958]
#
# Iteration:  21%|██        | 1030/4882 [02:19<08:28,  7.58it/s, learning_rate=1.2e-6, loss=0.1, step=1958]
#
# Iteration:  21%|██        | 1032/4882 [02:20<09:10,  6.99it/s, learning_rate=1.17e-6, loss=0.31, step=1959]
#
# Iteration:  21%|██        | 1034/4882 [02:20<08:45,  7.32it/s, learning_rate=1.17e-6, loss=0.31, step=1959]
#
# Iteration:  21%|██        | 1036/4882 [02:20<08:33,  7.49it/s, learning_rate=1.17e-6, loss=0.31, step=1959]
#
# Iteration:  21%|██▏       | 1038/4882 [02:20<08:28,  7.56it/s, learning_rate=1.17e-6, loss=0.31, step=1959]
#
# Iteration:  21%|██▏       | 1040/4882 [02:21<09:11,  6.96it/s, learning_rate=1.14e-6, loss=0.0984, step=1960]
#
# Iteration:  21%|██▏       | 1042/4882 [02:21<08:45,  7.31it/s, learning_rate=1.14e-6, loss=0.0984, step=1960]
#
# Iteration:  21%|██▏       | 1044/4882 [02:21<08:34,  7.46it/s, learning_rate=1.14e-6, loss=0.0984, step=1960]
#
# Iteration:  21%|██▏       | 1046/4882 [02:21<08:27,  7.56it/s, learning_rate=1.14e-6, loss=0.0984, step=1960]
#
# Iteration:  21%|██▏       | 1048/4882 [02:22<09:12,  6.94it/s, learning_rate=1.11e-6, loss=0.215, step=1961]
#
# Iteration:  22%|██▏       | 1050/4882 [02:22<08:45,  7.29it/s, learning_rate=1.11e-6, loss=0.215, step=1961]
#
# Iteration:  22%|██▏       | 1052/4882 [02:22<08:33,  7.46it/s, learning_rate=1.11e-6, loss=0.215, step=1961]
#
# Iteration:  22%|██▏       | 1054/4882 [02:23<08:26,  7.56it/s, learning_rate=1.11e-6, loss=0.215, step=1961]
#
# Iteration:  22%|██▏       | 1056/4882 [02:23<09:10,  6.95it/s, learning_rate=1.09e-6, loss=0.103, step=1962]
#
# Iteration:  22%|██▏       | 1058/4882 [02:23<08:45,  7.27it/s, learning_rate=1.09e-6, loss=0.103, step=1962]
#
# Iteration:  22%|██▏       | 1060/4882 [02:23<08:32,  7.45it/s, learning_rate=1.09e-6, loss=0.103, step=1962]
#
# Iteration:  22%|██▏       | 1062/4882 [02:24<08:27,  7.52it/s, learning_rate=1.09e-6, loss=0.103, step=1962]
#
# Iteration:  22%|██▏       | 1064/4882 [02:24<09:13,  6.90it/s, learning_rate=1.06e-6, loss=0.158, step=1963]
#
# Iteration:  22%|██▏       | 1066/4882 [02:24<08:46,  7.25it/s, learning_rate=1.06e-6, loss=0.158, step=1963]
#
# Iteration:  22%|██▏       | 1068/4882 [02:24<08:30,  7.47it/s, learning_rate=1.06e-6, loss=0.158, step=1963]
#
# Iteration:  22%|██▏       | 1070/4882 [02:25<08:24,  7.55it/s, learning_rate=1.06e-6, loss=0.158, step=1963]
#
# Iteration:  22%|██▏       | 1072/4882 [02:25<09:06,  6.98it/s, learning_rate=1.03e-6, loss=0.169, step=1964]
#
# Iteration:  22%|██▏       | 1074/4882 [02:25<08:41,  7.31it/s, learning_rate=1.03e-6, loss=0.169, step=1964]
#
# Iteration:  22%|██▏       | 1076/4882 [02:26<08:29,  7.48it/s, learning_rate=1.03e-6, loss=0.169, step=1964]
#
# Iteration:  22%|██▏       | 1078/4882 [02:26<08:23,  7.56it/s, learning_rate=1.03e-6, loss=0.169, step=1964]
#
# Iteration:  22%|██▏       | 1080/4882 [02:26<09:06,  6.96it/s, learning_rate=1e-6, loss=0.173, step=1965]
#
# Iteration:  22%|██▏       | 1082/4882 [02:26<08:40,  7.30it/s, learning_rate=1e-6, loss=0.173, step=1965]
#
# Iteration:  22%|██▏       | 1084/4882 [02:27<08:30,  7.44it/s, learning_rate=1e-6, loss=0.173, step=1965]
#
# Iteration:  22%|██▏       | 1086/4882 [02:27<08:22,  7.55it/s, learning_rate=1e-6, loss=0.173, step=1965]
#
# Iteration:  22%|██▏       | 1088/4882 [02:27<09:07,  6.93it/s, learning_rate=9.71e-7, loss=0.225, step=1966]
#
# Iteration:  22%|██▏       | 1090/4882 [02:27<08:39,  7.30it/s, learning_rate=9.71e-7, loss=0.225, step=1966]
#
# Iteration:  22%|██▏       | 1092/4882 [02:28<08:27,  7.46it/s, learning_rate=9.71e-7, loss=0.225, step=1966]
#
# Iteration:  22%|██▏       | 1094/4882 [02:28<08:20,  7.56it/s, learning_rate=9.71e-7, loss=0.225, step=1966]
#
# Iteration:  22%|██▏       | 1096/4882 [02:28<09:03,  6.97it/s, learning_rate=9.43e-7, loss=0.241, step=1967]
#
# Iteration:  22%|██▏       | 1098/4882 [02:29<08:37,  7.31it/s, learning_rate=9.43e-7, loss=0.241, step=1967]
#
# Iteration:  23%|██▎       | 1100/4882 [02:29<08:24,  7.50it/s, learning_rate=9.43e-7, loss=0.241, step=1967]
#
# Iteration:  23%|██▎       | 1102/4882 [02:29<08:19,  7.57it/s, learning_rate=9.43e-7, loss=0.241, step=1967]
#
# Iteration:  23%|██▎       | 1104/4882 [02:29<09:02,  6.97it/s, learning_rate=9.14e-7, loss=0.242, step=1968]
#
# Iteration:  23%|██▎       | 1106/4882 [02:30<08:36,  7.31it/s, learning_rate=9.14e-7, loss=0.242, step=1968]
#
# Iteration:  23%|██▎       | 1108/4882 [02:30<08:25,  7.47it/s, learning_rate=9.14e-7, loss=0.242, step=1968]
#
# Iteration:  23%|██▎       | 1110/4882 [02:30<08:19,  7.56it/s, learning_rate=9.14e-7, loss=0.242, step=1968]
#
# Iteration:  23%|██▎       | 1112/4882 [02:30<08:59,  6.99it/s, learning_rate=8.86e-7, loss=0.0983, step=1969]
#
# Iteration:  23%|██▎       | 1114/4882 [02:31<08:35,  7.31it/s, learning_rate=8.86e-7, loss=0.0983, step=1969]
#
# Iteration:  23%|██▎       | 1116/4882 [02:31<08:23,  7.48it/s, learning_rate=8.86e-7, loss=0.0983, step=1969]
#
# Iteration:  23%|██▎       | 1118/4882 [02:31<08:17,  7.57it/s, learning_rate=8.86e-7, loss=0.0983, step=1969]
#
# Iteration:  23%|██▎       | 1120/4882 [02:32<08:59,  6.97it/s, learning_rate=8.57e-7, loss=0.169, step=1970]
#
# Iteration:  23%|██▎       | 1122/4882 [02:32<08:34,  7.31it/s, learning_rate=8.57e-7, loss=0.169, step=1970]
#
# Iteration:  23%|██▎       | 1124/4882 [02:32<08:22,  7.49it/s, learning_rate=8.57e-7, loss=0.169, step=1970]
#
# Iteration:  23%|██▎       | 1126/4882 [02:32<08:16,  7.56it/s, learning_rate=8.57e-7, loss=0.169, step=1970]
#
# Iteration:  23%|██▎       | 1128/4882 [02:33<08:58,  6.97it/s, learning_rate=8.29e-7, loss=0.243, step=1971]
#
# Iteration:  23%|██▎       | 1130/4882 [02:33<08:33,  7.31it/s, learning_rate=8.29e-7, loss=0.243, step=1971]
#
# Iteration:  23%|██▎       | 1132/4882 [02:33<08:22,  7.47it/s, learning_rate=8.29e-7, loss=0.243, step=1971]
#
# Iteration:  23%|██▎       | 1134/4882 [02:33<08:17,  7.53it/s, learning_rate=8.29e-7, loss=0.243, step=1971]
#
# Iteration:  23%|██▎       | 1136/4882 [02:34<09:01,  6.91it/s, learning_rate=8e-7, loss=0.251, step=1972]
#
# Iteration:  23%|██▎       | 1138/4882 [02:34<08:37,  7.23it/s, learning_rate=8e-7, loss=0.251, step=1972]
#
# Iteration:  23%|██▎       | 1140/4882 [02:34<08:23,  7.43it/s, learning_rate=8e-7, loss=0.251, step=1972]
#
# Iteration:  23%|██▎       | 1142/4882 [02:35<08:15,  7.56it/s, learning_rate=8e-7, loss=0.251, step=1972]
#
# Iteration:  23%|██▎       | 1144/4882 [02:35<08:56,  6.97it/s, learning_rate=7.71e-7, loss=0.169, step=1973]
#
# Iteration:  23%|██▎       | 1146/4882 [02:35<08:32,  7.29it/s, learning_rate=7.71e-7, loss=0.169, step=1973]
#
# Iteration:  24%|██▎       | 1148/4882 [02:35<08:19,  7.47it/s, learning_rate=7.71e-7, loss=0.169, step=1973]
#
# Iteration:  24%|██▎       | 1150/4882 [02:36<08:15,  7.54it/s, learning_rate=7.71e-7, loss=0.169, step=1973]
#
# Iteration:  24%|██▎       | 1152/4882 [02:36<09:00,  6.90it/s, learning_rate=7.43e-7, loss=0.11, step=1974]
#
# Iteration:  24%|██▎       | 1154/4882 [02:36<08:35,  7.23it/s, learning_rate=7.43e-7, loss=0.11, step=1974]
#
# Iteration:  24%|██▎       | 1156/4882 [02:36<08:21,  7.43it/s, learning_rate=7.43e-7, loss=0.11, step=1974]
#
# Iteration:  24%|██▎       | 1158/4882 [02:37<08:16,  7.50it/s, learning_rate=7.43e-7, loss=0.11, step=1974]
#
# Iteration:  24%|██▍       | 1160/4882 [02:37<08:56,  6.94it/s, learning_rate=7.14e-7, loss=0.385, step=1975]
#
# Iteration:  24%|██▍       | 1162/4882 [02:37<08:33,  7.25it/s, learning_rate=7.14e-7, loss=0.385, step=1975]
#
# Iteration:  24%|██▍       | 1164/4882 [02:38<08:20,  7.42it/s, learning_rate=7.14e-7, loss=0.385, step=1975]
#
# Iteration:  24%|██▍       | 1166/4882 [02:38<08:13,  7.52it/s, learning_rate=7.14e-7, loss=0.385, step=1975]
#
# Iteration:  24%|██▍       | 1168/4882 [02:38<08:55,  6.94it/s, learning_rate=6.86e-7, loss=0.172, step=1976]
#
# Iteration:  24%|██▍       | 1170/4882 [02:38<08:31,  7.26it/s, learning_rate=6.86e-7, loss=0.172, step=1976]
#
# Iteration:  24%|██▍       | 1172/4882 [02:39<08:19,  7.43it/s, learning_rate=6.86e-7, loss=0.172, step=1976]
#
# Iteration:  24%|██▍       | 1174/4882 [02:39<08:13,  7.51it/s, learning_rate=6.86e-7, loss=0.172, step=1976]
#
# Iteration:  24%|██▍       | 1176/4882 [02:39<08:54,  6.93it/s, learning_rate=6.57e-7, loss=0.178, step=1977]
#
# Iteration:  24%|██▍       | 1178/4882 [02:39<08:29,  7.27it/s, learning_rate=6.57e-7, loss=0.178, step=1977]
#
# Iteration:  24%|██▍       | 1180/4882 [02:40<08:17,  7.44it/s, learning_rate=6.57e-7, loss=0.178, step=1977]
#
# Iteration:  24%|██▍       | 1182/4882 [02:40<08:12,  7.51it/s, learning_rate=6.57e-7, loss=0.178, step=1977]
#
# Iteration:  24%|██▍       | 1184/4882 [02:40<08:57,  6.88it/s, learning_rate=6.29e-7, loss=0.222, step=1978]
#
# Iteration:  24%|██▍       | 1186/4882 [02:41<08:31,  7.23it/s, learning_rate=6.29e-7, loss=0.222, step=1978]
#
# Iteration:  24%|██▍       | 1188/4882 [02:41<08:15,  7.45it/s, learning_rate=6.29e-7, loss=0.222, step=1978]
#
# Iteration:  24%|██▍       | 1190/4882 [02:41<08:10,  7.53it/s, learning_rate=6.29e-7, loss=0.222, step=1978]
#
# Iteration:  24%|██▍       | 1192/4882 [02:41<08:52,  6.93it/s, learning_rate=6e-7, loss=0.33, step=1979]
#
# Iteration:  24%|██▍       | 1194/4882 [02:42<08:27,  7.27it/s, learning_rate=6e-7, loss=0.33, step=1979]
#
# Iteration:  24%|██▍       | 1196/4882 [02:42<08:14,  7.45it/s, learning_rate=6e-7, loss=0.33, step=1979]
#
# Iteration:  25%|██▍       | 1198/4882 [02:42<08:07,  7.56it/s, learning_rate=6e-7, loss=0.33, step=1979]
#
# Iteration:  25%|██▍       | 1200/4882 [02:42<08:48,  6.97it/s, learning_rate=5.71e-7, loss=0.171, step=1980]
#
# Iteration:  25%|██▍       | 1202/4882 [02:43<08:24,  7.30it/s, learning_rate=5.71e-7, loss=0.171, step=1980]
#
# Iteration:  25%|██▍       | 1204/4882 [02:43<08:11,  7.48it/s, learning_rate=5.71e-7, loss=0.171, step=1980]
#
# Iteration:  25%|██▍       | 1206/4882 [02:43<08:07,  7.54it/s, learning_rate=5.71e-7, loss=0.171, step=1980]
#
# Iteration:  25%|██▍       | 1208/4882 [02:44<08:47,  6.96it/s, learning_rate=5.43e-7, loss=0.239, step=1981]
#
# Iteration:  25%|██▍       | 1210/4882 [02:44<08:23,  7.29it/s, learning_rate=5.43e-7, loss=0.239, step=1981]
#
# Iteration:  25%|██▍       | 1212/4882 [02:44<08:11,  7.46it/s, learning_rate=5.43e-7, loss=0.239, step=1981]
#
# Iteration:  25%|██▍       | 1214/4882 [02:44<08:05,  7.55it/s, learning_rate=5.43e-7, loss=0.239, step=1981]
#
# Iteration:  25%|██▍       | 1216/4882 [02:45<08:44,  6.99it/s, learning_rate=5.14e-7, loss=0.31, step=1982]
#
# Iteration:  25%|██▍       | 1218/4882 [02:45<08:23,  7.28it/s, learning_rate=5.14e-7, loss=0.31, step=1982]
#
# Iteration:  25%|██▍       | 1220/4882 [02:45<08:11,  7.45it/s, learning_rate=5.14e-7, loss=0.31, step=1982]
#
# Iteration:  25%|██▌       | 1222/4882 [02:45<08:07,  7.51it/s, learning_rate=5.14e-7, loss=0.31, step=1982]
#
# Iteration:  25%|██▌       | 1224/4882 [02:46<08:48,  6.92it/s, learning_rate=4.86e-7, loss=0.171, step=1983]
#
# Iteration:  25%|██▌       | 1226/4882 [02:46<08:22,  7.27it/s, learning_rate=4.86e-7, loss=0.171, step=1983]
#
# Iteration:  25%|██▌       | 1228/4882 [02:46<08:10,  7.45it/s, learning_rate=4.86e-7, loss=0.171, step=1983]
#
# Iteration:  25%|██▌       | 1230/4882 [02:47<08:03,  7.55it/s, learning_rate=4.86e-7, loss=0.171, step=1983]
#
# Iteration:  25%|██▌       | 1232/4882 [02:47<08:44,  6.96it/s, learning_rate=4.57e-7, loss=0.0988, step=1984]
#
# Iteration:  25%|██▌       | 1234/4882 [02:47<08:18,  7.32it/s, learning_rate=4.57e-7, loss=0.0988, step=1984]
#
# Iteration:  25%|██▌       | 1236/4882 [02:47<08:07,  7.49it/s, learning_rate=4.57e-7, loss=0.0988, step=1984]
#
# Iteration:  25%|██▌       | 1238/4882 [02:48<08:02,  7.56it/s, learning_rate=4.57e-7, loss=0.0988, step=1984]
#
# Iteration:  25%|██▌       | 1240/4882 [02:48<08:45,  6.93it/s, learning_rate=4.29e-7, loss=0.435, step=1985]
#
# Iteration:  25%|██▌       | 1242/4882 [02:48<08:19,  7.29it/s, learning_rate=4.29e-7, loss=0.435, step=1985]
#
# Iteration:  25%|██▌       | 1244/4882 [02:48<08:07,  7.46it/s, learning_rate=4.29e-7, loss=0.435, step=1985]
#
# Iteration:  26%|██▌       | 1246/4882 [02:49<08:00,  7.56it/s, learning_rate=4.29e-7, loss=0.435, step=1985]
#
# Iteration:  26%|██▌       | 1248/4882 [02:49<08:43,  6.94it/s, learning_rate=4e-7, loss=0.132, step=1986]
#
# Iteration:  26%|██▌       | 1250/4882 [02:49<08:19,  7.28it/s, learning_rate=4e-7, loss=0.132, step=1986]
#
# Iteration:  26%|██▌       | 1252/4882 [02:50<08:05,  7.47it/s, learning_rate=4e-7, loss=0.132, step=1986]
#
# Iteration:  26%|██▌       | 1254/4882 [02:50<07:59,  7.56it/s, learning_rate=4e-7, loss=0.132, step=1986]
#
# Iteration:  26%|██▌       | 1256/4882 [02:50<08:40,  6.97it/s, learning_rate=3.71e-7, loss=0.0985, step=1987]
#
# Iteration:  26%|██▌       | 1258/4882 [02:50<08:15,  7.31it/s, learning_rate=3.71e-7, loss=0.0985, step=1987]
#
# Iteration:  26%|██▌       | 1260/4882 [02:51<08:04,  7.48it/s, learning_rate=3.71e-7, loss=0.0985, step=1987]
#
# Iteration:  26%|██▌       | 1262/4882 [02:51<07:57,  7.58it/s, learning_rate=3.71e-7, loss=0.0985, step=1987]
#
# Iteration:  26%|██▌       | 1264/4882 [02:51<08:42,  6.93it/s, learning_rate=3.43e-7, loss=0.157, step=1988]
#
# Iteration:  26%|██▌       | 1266/4882 [02:51<08:16,  7.29it/s, learning_rate=3.43e-7, loss=0.157, step=1988]
#
# Iteration:  26%|██▌       | 1268/4882 [02:52<08:03,  7.47it/s, learning_rate=3.43e-7, loss=0.157, step=1988]
#
# Iteration:  26%|██▌       | 1270/4882 [02:52<07:58,  7.56it/s, learning_rate=3.43e-7, loss=0.157, step=1988]
#
# Iteration:  26%|██▌       | 1272/4882 [02:52<08:37,  6.97it/s, learning_rate=3.14e-7, loss=0.242, step=1989]
#
# Iteration:  26%|██▌       | 1274/4882 [02:53<08:14,  7.30it/s, learning_rate=3.14e-7, loss=0.242, step=1989]
#
# Iteration:  26%|██▌       | 1276/4882 [02:53<08:01,  7.48it/s, learning_rate=3.14e-7, loss=0.242, step=1989]
#
# Iteration:  26%|██▌       | 1278/4882 [02:53<07:57,  7.54it/s, learning_rate=3.14e-7, loss=0.242, step=1989]
#
# Iteration:  26%|██▌       | 1280/4882 [02:53<08:38,  6.94it/s, learning_rate=2.86e-7, loss=0.17, step=1990]
#
# Iteration:  26%|██▋       | 1282/4882 [02:54<08:14,  7.29it/s, learning_rate=2.86e-7, loss=0.17, step=1990]
#
# Iteration:  26%|██▋       | 1284/4882 [02:54<08:00,  7.48it/s, learning_rate=2.86e-7, loss=0.17, step=1990]
#
# Iteration:  26%|██▋       | 1286/4882 [02:54<07:54,  7.57it/s, learning_rate=2.86e-7, loss=0.17, step=1990]
#
# Iteration:  26%|██▋       | 1288/4882 [02:54<08:37,  6.94it/s, learning_rate=2.57e-7, loss=0.17, step=1991]
#
# Iteration:  26%|██▋       | 1290/4882 [02:55<08:12,  7.29it/s, learning_rate=2.57e-7, loss=0.17, step=1991]
#
# Iteration:  26%|██▋       | 1292/4882 [02:55<08:01,  7.46it/s, learning_rate=2.57e-7, loss=0.17, step=1991]
#
# Iteration:  27%|██▋       | 1294/4882 [02:55<07:57,  7.52it/s, learning_rate=2.57e-7, loss=0.17, step=1991]
#
# Iteration:  27%|██▋       | 1296/4882 [02:56<08:36,  6.94it/s, learning_rate=2.29e-7, loss=0.17, step=1992]
#
# Iteration:  27%|██▋       | 1298/4882 [02:56<08:11,  7.29it/s, learning_rate=2.29e-7, loss=0.17, step=1992]
#
# Iteration:  27%|██▋       | 1300/4882 [02:56<08:00,  7.46it/s, learning_rate=2.29e-7, loss=0.17, step=1992]
#
# Iteration:  27%|██▋       | 1302/4882 [02:56<07:54,  7.55it/s, learning_rate=2.29e-7, loss=0.17, step=1992]
#
# Iteration:  27%|██▋       | 1304/4882 [02:57<08:33,  6.96it/s, learning_rate=2e-7, loss=0.0987, step=1993]
#
# Iteration:  27%|██▋       | 1306/4882 [02:57<08:09,  7.30it/s, learning_rate=2e-7, loss=0.0987, step=1993]
#
# Iteration:  27%|██▋       | 1308/4882 [02:57<07:58,  7.47it/s, learning_rate=2e-7, loss=0.0987, step=1993]
#
# Iteration:  27%|██▋       | 1310/4882 [02:57<07:52,  7.57it/s, learning_rate=2e-7, loss=0.0987, step=1993]
#
# Iteration:  27%|██▋       | 1312/4882 [02:58<08:33,  6.96it/s, learning_rate=1.71e-7, loss=0.1, step=1994]
#
# Iteration:  27%|██▋       | 1314/4882 [02:58<08:08,  7.30it/s, learning_rate=1.71e-7, loss=0.1, step=1994]
#
# Iteration:  27%|██▋       | 1316/4882 [02:58<07:56,  7.49it/s, learning_rate=1.71e-7, loss=0.1, step=1994]
#
# Iteration:  27%|██▋       | 1318/4882 [02:58<07:51,  7.56it/s, learning_rate=1.71e-7, loss=0.1, step=1994]
#
# Iteration:  27%|██▋       | 1320/4882 [02:59<08:29,  6.98it/s, learning_rate=1.43e-7, loss=0.102, step=1995]
#
# Iteration:  27%|██▋       | 1322/4882 [02:59<08:06,  7.32it/s, learning_rate=1.43e-7, loss=0.102, step=1995]
#
# Iteration:  27%|██▋       | 1324/4882 [02:59<07:55,  7.49it/s, learning_rate=1.43e-7, loss=0.102, step=1995]
#
# Iteration:  27%|██▋       | 1326/4882 [03:00<07:51,  7.53it/s, learning_rate=1.43e-7, loss=0.102, step=1995]
#
# Iteration:  27%|██▋       | 1328/4882 [03:00<08:32,  6.94it/s, learning_rate=1.14e-7, loss=0.0981, step=1996]
#
# Iteration:  27%|██▋       | 1330/4882 [03:00<08:08,  7.27it/s, learning_rate=1.14e-7, loss=0.0981, step=1996]
#
# Iteration:  27%|██▋       | 1332/4882 [03:00<07:58,  7.42it/s, learning_rate=1.14e-7, loss=0.0981, step=1996]
#
# Iteration:  27%|██▋       | 1334/4882 [03:01<07:51,  7.52it/s, learning_rate=1.14e-7, loss=0.0981, step=1996]
#
# Iteration:  27%|██▋       | 1336/4882 [03:01<08:28,  6.97it/s, learning_rate=8.57e-8, loss=0.169, step=1997]
#
# Iteration:  27%|██▋       | 1338/4882 [03:01<08:05,  7.30it/s, learning_rate=8.57e-8, loss=0.169, step=1997]
#
# Iteration:  27%|██▋       | 1340/4882 [03:01<07:55,  7.45it/s, learning_rate=8.57e-8, loss=0.169, step=1997]
#
# Iteration:  27%|██▋       | 1342/4882 [03:02<07:49,  7.54it/s, learning_rate=8.57e-8, loss=0.169, step=1997]
#
# Iteration:  28%|██▊       | 1344/4882 [03:02<08:27,  6.97it/s, learning_rate=5.71e-8, loss=0.313, step=1998]
#
# Iteration:  28%|██▊       | 1346/4882 [03:02<08:04,  7.29it/s, learning_rate=5.71e-8, loss=0.313, step=1998]
#
# Iteration:  28%|██▊       | 1348/4882 [03:03<07:52,  7.47it/s, learning_rate=5.71e-8, loss=0.313, step=1998]
#
# Iteration:  28%|██▊       | 1350/4882 [03:03<07:49,  7.53it/s, learning_rate=5.71e-8, loss=0.313, step=1998]
#
# Iteration:  28%|██▊       | 1352/4882 [03:03<08:29,  6.93it/s, learning_rate=2.86e-8, loss=0.172, step=1999]
#
# Iteration:  28%|██▊       | 1354/4882 [03:03<08:06,  7.26it/s, learning_rate=2.86e-8, loss=0.172, step=1999]
#
# Iteration:  28%|██▊       | 1356/4882 [03:04<07:53,  7.45it/s, learning_rate=2.86e-8, loss=0.172, step=1999]
#
# Iteration:  28%|██▊       | 1358/4882 [03:04<07:47,  7.54it/s, learning_rate=2.86e-8, loss=0.172, step=1999]
#
# Iteration:  28%|██▊       | 1360/4882 [03:04<08:28,  6.93it/s, learning_rate=0, loss=0.107, step=2000]
#
# Iteration:  28%|██▊       | 1362/4882 [03:05<08:04,  7.27it/s, learning_rate=0, loss=0.107, step=2000]
#
# Iteration:  28%|██▊       | 1364/4882 [03:05<07:53,  7.43it/s, learning_rate=0, loss=0.107, step=2000]
#
# Iteration:  28%|██▊       | 1366/4882 [03:05<07:46,  7.53it/s, learning_rate=0, loss=0.107, step=2000]
#
# Iteration:  28%|██▊       | 1367/4882 [03:05<07:57,  7.36it/s, learning_rate=0, loss=0.253, step=2001]
# Epoch:  75%|███████▌  | 3/4 [36:45<12:15, 735.04s/it]
# (2001, 0.32422935922463975)

# %% [markdown]
# ## Evaluate our trained model

# %%
model.eval()
logging.info("putting model in eval mode")
# Out:
# INFO:root:putting model in eval mode

# %%
results = pd.DataFrame(evaluate("../../Rodrigo-data/Finetuning/dbrd/test", model,debias=DEBIAS_BOOL, bias_dir=bias_direction))
# Out:
#   0%|          | 0/2224 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 55/2224 [00:01<00:39, 54.40it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▍         | 110/2224 [00:02<00:38, 54.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 164/2224 [00:03<00:38, 54.07it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 216/2224 [00:04<00:37, 53.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 268/2224 [00:05<00:37, 52.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 323/2224 [00:06<00:35, 53.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 376/2224 [00:07<00:34, 53.21it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 430/2224 [00:08<00:33, 53.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 482/2224 [00:09<00:32, 52.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 537/2224 [00:10<00:31, 53.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 592/2224 [00:11<00:30, 53.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 647/2224 [00:12<00:29, 53.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 700/2224 [00:13<00:28, 53.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 755/2224 [00:14<00:27, 53.60it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▋      | 809/2224 [00:15<00:26, 52.71it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | 863/2224 [00:16<00:25, 52.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 916/2224 [00:17<00:24, 52.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▎     | 969/2224 [00:18<00:23, 52.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▌     | 1022/2224 [00:19<00:22, 52.60it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 1077/2224 [00:20<00:21, 53.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████     | 1133/2224 [00:21<00:20, 53.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 1187/2224 [00:22<00:19, 53.55it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 1241/2224 [00:23<00:18, 53.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 1295/2224 [00:24<00:17, 53.18it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  61%|██████    | 1351/2224 [00:25<00:16, 53.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 1407/2224 [00:26<00:15, 54.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  66%|██████▌   | 1462/2224 [00:27<00:14, 54.42it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 1519/2224 [00:28<00:12, 54.96it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  71%|███████   | 1574/2224 [00:29<00:11, 54.91it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  73%|███████▎  | 1629/2224 [00:30<00:11, 53.94it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▌  | 1683/2224 [00:31<00:10, 53.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | 1737/2224 [00:32<00:09, 53.78it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 1791/2224 [00:33<00:08, 53.66it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 1845/2224 [00:34<00:07, 53.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▌ | 1899/2224 [00:35<00:06, 53.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 1953/2224 [00:36<00:05, 53.48it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 2008/2224 [00:37<00:04, 53.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 2063/2224 [00:38<00:02, 54.21it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 2118/2224 [00:39<00:01, 53.99it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 2174/2224 [00:40<00:00, 54.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 2224/2224 [00:41<00:00, 53.58it/s]

# %%
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, aspect="equal")
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.ylim(len(tick_marks) - 0.5, -0.5)
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_matrix = confusion_matrix(results['true'], results['predicted'] ) # index to evaluate partial runs

np.set_printoptions(precision=2)

title="Confusion matrix"

# Plot normalized confusion matrix
fig = plt.figure(figsize=(5,5), dpi=100)
#fig.set_size_inches(6,6)

plot_confusion_matrix(cnf_matrix, classes=["Negative", "Positive"],normalize=False, 
                      title=title, cmap=plt.cm.Blues)
# Out:
# Confusion matrix, without normalization
# [[  56 1056]
#  [1048   64]]

# %%
cm = ConfusionMatrix(actual_vector=results['true'].values, predict_vector=results['predicted'].values )

# %%
cm.stat()
# Out:
# Overall Statistics :
#
# 95% CI                                                            (0.04457,0.06335)
# ACC Macro                                                         0.05396
# ARI                                                               0.79573
# AUNP                                                              0.05396
# AUNU                                                              0.05396
# Bangdiwala B                                                      0.00292
# Bennett S                                                         -0.89209
# CBA                                                               0.05375
# CSI                                                               -0.89211
# Chi-Squared                                                       1769.99089
# Chi-Squared DF                                                    1
# Conditional Entropy                                               0.30279
# Cramer V                                                          0.89211
# Cross Entropy                                                     1.00004
# F1 Macro                                                          0.05394
# F1 Micro                                                          0.05396
# FNR Macro                                                         0.94604
# FNR Micro                                                         0.94604
# FPR Macro                                                         0.94604
# FPR Micro                                                         0.94604
# Gwet AC1                                                          -0.89206
# Hamming Loss                                                      0.94604
# Joint Entropy                                                     1.30279
# KL Divergence                                                     4e-05
# Kappa                                                             -0.89209
# Kappa 95% CI                                                      (-0.91087,-0.87331)
# Kappa No Prevalence                                               -0.89209
# Kappa Standard Error                                              0.00958
# Kappa Unbiased                                                    -0.89211
# Krippendorff Alpha                                                -0.89169
# Lambda A                                                          0.89209
# Lambda B                                                          0.8913
# Mutual Information                                                0.69717
# NIR                                                               0.5
# Overall ACC                                                       0.05396
# Overall CEN                                                       1.02173
# Overall J                                                         (0.05545,0.02772)
# Overall MCC                                                       -0.89211
# Overall MCEN                                                      0.98441
# Overall RACC                                                      0.5
# Overall RACCU                                                     0.50001
# P-Value                                                           1.0
# PPV Macro                                                         0.05393
# PPV Micro                                                         0.05396
# Pearson C                                                         0.66571
# Phi-Squared                                                       0.79586
# RCI                                                               0.69717
# RR                                                                1112.0
# Reference Entropy                                                 1.0
# Response Entropy                                                  0.99996
# SOA1(Landis & Koch)                                               Poor
# SOA2(Fleiss)                                                      Poor
# SOA3(Altman)                                                      Poor
# SOA4(Cicchetti)                                                   Poor
# SOA5(Cramer)                                                      Very Strong
# SOA6(Matthews)                                                    Negligible
# Scott PI                                                          -0.89211
# Standard Error                                                    0.00479
# TNR Macro                                                         0.05396
# TNR Micro                                                         0.05396
# TPR Macro                                                         0.05396
# TPR Micro                                                         0.05396
# Zero-one Loss                                                     2104
#
# Class Statistics :
#
# Classes                                                           0             1
# ACC(Accuracy)                                                     0.05396       0.05396
# AGF(Adjusted F-score)                                             0.05372       0.05395
# AGM(Adjusted geometric mean)                                      0.05508       0.05268
# AM(Difference between automatic and manual classification)        -8            8
# AUC(Area under the ROC curve)                                     0.05396       0.05396
# AUCI(AUC value interpretation)                                    Poor          Poor
# AUPR(Area under the PR curve)                                     0.05054       0.05735
# BCD(Bray-Curtis dissimilarity)                                    0.0018        0.0018
# BM(Informedness or bookmaker informedness)                        -0.89209      -0.89209
# CEN(Confusion entropy)                                            1.02049       1.02296
# DOR(Diagnostic odds ratio)                                        0.00324       0.00324
# DP(Discriminant power)                                            -1.37262      -1.37262
# DPI(Discriminant power interpretation)                            Poor          Poor
# ERR(Error rate)                                                   0.94604       0.94604
# F0.5(F0.5 score)                                                  0.05065       0.05722
# F1(F1 score - harmonic mean of precision and sensitivity)         0.05054       0.05735
# F2(F2 score)                                                      0.05043       0.05747
# FDR(False discovery rate)                                         0.94928       0.94286
# FN(False negative/miss/type 2 error)                              1056          1048
# FNR(Miss rate or false negative rate)                             0.94964       0.94245
# FOR(False omission rate)                                          0.94286       0.94928
# FP(False positive/type 1 error/false alarm)                       1048          1056
# FPR(Fall-out or false positive rate)                              0.94245       0.94964
# G(G-measure geometric mean of precision and sensitivity)          0.05054       0.05735
# GI(Gini index)                                                    -0.89209      -0.89209
# GM(G-mean geometric mean of specificity and sensitivity)          0.05384       0.05384
# IBA(Index of balanced accuracy)                                   0.00288       0.00292
# ICSI(Individual classification success index)                     -0.89892      -0.8853
# IS(Information score)                                             -3.30117      -3.12928
# J(Jaccard index)                                                  0.02593       0.02952
# LS(Lift score)                                                    0.10145       0.11429
# MCC(Matthews correlation coefficient)                             -0.89211      -0.89211
# MCCI(Matthews correlation coefficient interpretation)             Negligible    Negligible
# MCEN(Modified confusion entropy)                                  1.01098       1.01242
# MK(Markedness)                                                    -0.89213      -0.89213
# N(Condition negative)                                             1112          1112
# NLR(Negative likelihood ratio)                                    16.5          18.71429
# NLRI(Negative likelihood ratio interpretation)                    Negligible    Negligible
# NPV(Negative predictive value)                                    0.05714       0.05072
# OC(Overlap coefficient)                                           0.05072       0.05755
# OOC(Otsuka-Ochiai coefficient)                                    0.05054       0.05735
# OP(Optimized precision)                                           -0.01271      -0.01271
# P(Condition positive or support)                                  1112          1112
# PLR(Positive likelihood ratio)                                    0.05344       0.06061
# PLRI(Positive likelihood ratio interpretation)                    Negligible    Negligible
# POP(Population)                                                   2224          2224
# PPV(Precision or positive predictive value)                       0.05072       0.05714
# PRE(Prevalence)                                                   0.5           0.5
# Q(Yule Q - coefficient of colligation)                            -0.99354      -0.99354
# QI(Yule Q interpretation)                                         Negligible    Negligible
# RACC(Random accuracy)                                             0.2482        0.2518
# RACCU(Random accuracy unbiased)                                   0.2482        0.2518
# TN(True negative/correct rejection)                               64            56
# TNR(Specificity or true negative rate)                            0.05755       0.05036
# TON(Test outcome negative)                                        1120          1104
# TOP(Test outcome positive)                                        1104          1120
# TP(True positive/hit)                                             56            64
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.05036       0.05755
# Y(Youden index)                                                   -0.89209      -0.89209
# dInd(Distance index)                                              1.33792       1.33792
# sInd(Similarity index)                                            0.05395       0.05395

# %%
import pickle
# file_pickle_stats =  "../../Rodrigo-data/Finetuning/dbrd/v2/cm_stat_bertje_debiased"

file_pickle_stats =  "../../Rodrigo-data/Finetuning/dbrd/v2/cm_stat_bertje_biased"
pickle.dump( cm, open(file_pickle_stats+".p", "wb" ))
st_test =pickle.load( open(file_pickle_stats+".p", "rb" ))
cm.save_csv(file_pickle_stats) #save csv for easy to read
# Out:
# {'Status': True,
#  'Message': '/home/ubuntu/thesis/Rodrigo-Debias-Dutch-Embeddings/Rodrigo-notebooks/Finetuning/../../Rodrigo-data/Finetuning/dbrd/v2/cm_stat_bertje_biased.csv'}

# %% [markdown]
# ## Saving the model

# %%
from transformers import WEIGHTS_NAME, CONFIG_NAME

# output_dir = "../../Rodrigo-data/Finetuning/dbrd/v2/bert_debiased/"
output_dir = "../../Rodrigo-data/Finetuning/dbrd/v2/bert_biased/"

# Step 1: Save a model, configuration and vocabulary that you have fine-tuned

# If we have a distributed model, save only the encapsulated model
# (it was wrapped in PyTorch DistributedDataParallel or DataParallel)
model_to_save = model.module if hasattr(model, 'module') else model

# If we save using the predefined names, we can load using `from_pretrained`
output_model_file = os.path.join(output_dir, WEIGHTS_NAME)
output_config_file = os.path.join(output_dir, CONFIG_NAME)

torch.save(model_to_save.state_dict(), output_model_file)
model_to_save.config.to_json_file(output_config_file)
tokenizer.save_vocabulary(output_dir)
# Out:
# ('../../Rodrigo-data/Finetuning/dbrd/v2/bert_biased/vocab.txt',)
